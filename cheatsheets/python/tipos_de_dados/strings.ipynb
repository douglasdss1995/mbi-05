# %%
# Operações com strings
texto = "Python é incrível"

# %%
texto.upper()  # "PYTHON É INCRÍVEL"
# Out:
# 'PYTHON É INCRÍVEL'

# %%
texto.lower()
# Out:
# 'python é incrível'

# %%
texto.title()  # "Python É Incrível"
# Out:
# 'Python É Incrível'

# %%
# Remover espaços em branco no início e fim
texto.strip()
# Out:
# 'Python é incrível'

# %%
# Dividi a string em uma lista com base no caracatere
texto.split(" ")
